# %% [markdown]
# # Bước 6: Phân cụm khách hàng từ Luật kết hợp (Association Rules → Clustering)
#
# Notebook này lấy **kết quả luật kết hợp** (Apriori/FP-Growth) và biến chúng thành **đặc trưng** để phân cụm khách hàng bằng K-Means.
#
# ## Ý tưởng cốt lõi
# - Mỗi luật có dạng: **Antecedent → Consequent**
# - Với mỗi khách hàng, ta kiểm tra: khách đó đã từng mua **đủ antecedents** của luật hay chưa.
# - Mỗi luật trở thành một feature (0/1 hoặc có trọng số theo lift/confidence).
# - (Tuỳ chọn) Ghép thêm **RFM** để phân cụm ổn định hơn.

# %% [markdown]
# ## Parameters
# Gán tham số để chạy bằng papermill.

# %%
# PARAMETERS (for papermill)

# Input
CLEANED_DATA_PATH = "../data/processed/cleaned_uk_data.csv"
RULES_INPUT_PATH = "../data/processed/rules_fpgrowth_filtered.csv"  # hoặc rules_fpgrowth_filtered.csv

# Feature engineering
TOP_K_RULES = 200
SORT_RULES_BY = "lift"      # lift | confidence | support
WEIGHTING = "lift_x_conf"          # none | lift | confidence | support | lift_x_conf
MIN_ANTECEDENT_LEN = 2
USE_RFM = True
RFM_SCALE = True
RULE_SCALE = False

# Clustering
K_MIN = 2
K_MAX = 10
N_CLUSTERS = None            # None => chọn theo silhouette, hoặc đặt số cụ thể (vd 5)
RANDOM_STATE = 42

# Output
OUTPUT_CLUSTER_PATH = "data/processed/customer_clusters_from_rules.csv"

# Visual
PROJECTION_METHOD = "pca"   # pca | svd
PLOT_2D = True

# %%
# Parameters
CLEANED_DATA_PATH = "data/processed/cleaned_uk_data.csv"
RULES_INPUT_PATH = "data/processed/rules_fpgrowth_filtered.csv"
TOP_K_RULES = 250
SORT_RULES_BY = "lift"
WEIGHTING = "binary"
MIN_ANTECEDENT_LEN = 2
USE_RFM = False
RFM_SCALE = False
RULE_SCALE = False
K_MIN = 2
K_MAX = 10
N_CLUSTERS = None
RANDOM_STATE = 42
OUTPUT_CLUSTER_PATH = "data/processed/customer_clusters_baseline.csv"
PROJECTION_METHOD = "pca"
PLOT_2D = True

# %% [markdown]
# ## Set up

# %%
# %load_ext autoreload
# %autoreload 2

import os
import sys
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Determine correct project root
cwd = os.getcwd()
if os.path.basename(cwd) == "notebooks":
    project_root = os.path.abspath("..")
else:
    project_root = cwd

src_path = os.path.join(project_root, "src")
if src_path not in sys.path:
    sys.path.append(src_path)

from cluster_library import RuleBasedCustomerClusterer

# %% [markdown]
# ## Load cleaned data & rules

# %%
df_clean = pd.read_csv(CLEANED_DATA_PATH, parse_dates=["InvoiceDate"])
print(df_clean.shape)
df_clean.head()
# Out:
# (485123, 11)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_20136\4012976299.py:1: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_clean = pd.read_csv(CLEANED_DATA_PATH, parse_dates=["InvoiceDate"])
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice CustomerID         Country  TotalPrice  \
# 0 2010-12-01 08:26:00       2.55     017850  United Kingdom       15.30
# 1 2010-12-01 08:26:00       3.39     017850  United Kingdom       20.34
# 2 2010-12-01 08:26:00       2.75     017850  United Kingdom       22.00
# 3 2010-12-01 08:26:00       3.39     017850  United Kingdom       20.34
# 4 2010-12-01 08:26:00       3.39     017850  United Kingdom       20.34
#
#    DayOfWeek  HourOfDay
# 0          2          8
# 1          2          8
# 2          2          8
# 3          2          8
# 4          2          8

# %%
clusterer = RuleBasedCustomerClusterer(df_clean=df_clean)
customer_item_bool = clusterer.build_customer_item_matrix(threshold=1)
print('Customer × Item:', customer_item_bool.shape)

rules_df = clusterer.load_rules(
    rules_csv_path=RULES_INPUT_PATH,
    top_k=TOP_K_RULES,
    sort_by=SORT_RULES_BY,
)
print('Rules used:', rules_df.shape)
rules_df.head()
# Out:
# Customer × Item: (3921, 4007)
# Rules used: (250, 17)
#                                          antecedents  \
# 0  frozenset({'HERB MARKER ROSEMARY', 'HERB MARKE...
# 1  frozenset({'HERB MARKER MINT', 'HERB MARKER TH...
# 2  frozenset({'HERB MARKER MINT', 'HERB MARKER TH...
# 3  frozenset({'HERB MARKER PARSLEY', 'HERB MARKER...
# 4  frozenset({'HERB MARKER BASIL', 'HERB MARKER T...
#
#                            consequents  antecedent support  \
# 0     frozenset({'HERB MARKER THYME'})            0.011487
# 1  frozenset({'HERB MARKER ROSEMARY'})            0.011098
# 2   frozenset({'HERB MARKER PARSLEY'})            0.011098
# 3  frozenset({'HERB MARKER ROSEMARY'})            0.011487
# 4  frozenset({'HERB MARKER ROSEMARY'})            0.011265
#
#    consequent support   support  confidence       lift  representativity  \
# 0            0.012763  0.010932    0.951691  74.567045               1.0
# 1            0.012818  0.010599    0.955000  74.502403               1.0
# 2            0.012652  0.010432    0.940000  74.297105               1.0
# 3            0.012818  0.010932    0.951691  74.244244               1.0
# 4            0.012818  0.010710    0.950739  74.169983               1.0
#
#    leverage  conviction  zhangs_metric   jaccard  certainty  kulczynski  \
# 0  0.010785   20.435808       0.998053  0.820833   0.951066    0.904106
# 1  0.010456   21.937369       0.997650  0.795833   0.954416    0.890920
# 2  0.010292   16.455802       0.997612  0.783333   0.939231    0.882281
# 3  0.010784   20.434660       0.997995  0.817427   0.951064    0.902252
# 4  0.010565   20.039787       0.997757  0.800830   0.950099    0.893118
#
#                              antecedents_str       consequents_str  \
# 0  HERB MARKER PARSLEY, HERB MARKER ROSEMARY     HERB MARKER THYME
# 1        HERB MARKER MINT, HERB MARKER THYME  HERB MARKER ROSEMARY
# 2        HERB MARKER MINT, HERB MARKER THYME   HERB MARKER PARSLEY
# 3     HERB MARKER PARSLEY, HERB MARKER THYME  HERB MARKER ROSEMARY
# 4       HERB MARKER BASIL, HERB MARKER THYME  HERB MARKER ROSEMARY
#
#                                             rule_str
# 0  HERB MARKER PARSLEY, HERB MARKER ROSEMARY → HE...
# 1  HERB MARKER MINT, HERB MARKER THYME → HERB MAR...
# 2  HERB MARKER MINT, HERB MARKER THYME → HERB MAR...
# 3  HERB MARKER PARSLEY, HERB MARKER THYME → HERB ...
# 4  HERB MARKER BASIL, HERB MARKER THYME → HERB MA...

# %% [markdown]
# ## Build features (Rules → Features) + (optional) RFM

# %%
X, meta = clusterer.build_final_features(
    weighting=WEIGHTING,
    use_rfm=USE_RFM,
    rfm_scale=RFM_SCALE,
    rule_scale=RULE_SCALE,
    min_antecedent_len=MIN_ANTECEDENT_LEN,
)
print('X shape:', X.shape)
meta.head()
# Out:
# X shape: (3921, 250)
#   CustomerID
# 0     000nan
# 1     012346
# 2     012747
# 3     012748
# 4     012749

# %% [markdown]
# ## Choose K (silhouette)

# %%
sil_df = clusterer.choose_k_by_silhouette(
    X,
    k_min=K_MIN,
    k_max=K_MAX,
    random_state=RANDOM_STATE,
)
sil_df
# Out:
# C:\Users\Admin\anaconda3\Lib\site-packages\joblib\externals\loky\backend\context.py:136: UserWarning: Could not find the number of physical cores for the following reason:
# [WinError 2] The system cannot find the file specified
# Returning the number of logical cores instead. You can silence this warning by setting LOKY_MAX_CPU_COUNT to the number of cores you want to use.
#   warnings.warn(
#   File "C:\Users\Admin\anaconda3\Lib\site-packages\joblib\externals\loky\backend\context.py", line 257, in _count_physical_cores
#     cpu_info = subprocess.run(
#                ^^^^^^^^^^^^^^^
#   File "C:\Users\Admin\anaconda3\Lib\subprocess.py", line 548, in run
#     with Popen(*popenargs, **kwargs) as process:
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Admin\anaconda3\Lib\subprocess.py", line 1026, in __init__
#     self._execute_child(args, executable, preexec_fn, close_fds,
#   File "C:\Users\Admin\anaconda3\Lib\subprocess.py", line 1538, in _execute_child
#     hp, ht, pid, tid = _winapi.CreateProcess(executable, args,
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     k  silhouette
# 0   3    0.845860
# 1   4    0.832606
# 2   5    0.822349
# 3   6    0.807288
# 4   2    0.800137
# 5   9    0.759516
# 6   8    0.759305
# 7  10    0.759195
# 8   7    0.738061

# %%
best_k = int(sil_df.loc[0, 'k'])
N_CLUSTERS = 4
k = best_k if N_CLUSTERS is None else int(N_CLUSTERS)
print('Chosen k =', k)
# Out:
# Chosen k = 4

# %% [markdown]
# ## Fit KMeans & save results

# %%
labels = clusterer.fit_kmeans(X, n_clusters=k, random_state=RANDOM_STATE)
meta_out = meta.copy()
meta_out['cluster'] = labels

# Lưu
os.makedirs(os.path.dirname(OUTPUT_CLUSTER_PATH), exist_ok=True)
meta_out.to_csv(OUTPUT_CLUSTER_PATH, index=False)
print('Saved:', OUTPUT_CLUSTER_PATH)
meta_out.head()
# Out:
# Saved: data/processed/customer_clusters_baseline.csv
#   CustomerID  cluster
# 0     000nan        1
# 1     012346        0
# 2     012747        0
# 3     012748        1
# 4     012749        0

# %% [markdown]
# ## Quick profiling

# %%
profile_cols = ['cluster'] + ([c for c in ['Recency','Frequency','Monetary'] if c in meta_out.columns])
summary = meta_out.groupby('cluster').agg({
    'CustomerID': 'count',
    **{c:'mean' for c in profile_cols if c!='cluster'}
}).rename(columns={'CustomerID':'n_customers'}).sort_values('n_customers', ascending=False)
summary
# Out:
#          n_customers
# cluster
# 0               3686
# 2                116
# 3                111
# 1                  8

# %% [markdown]
# ## 2D visualization (PCA/SVD)

# %%
if PLOT_2D:
    Z = clusterer.project_2d(X, method=PROJECTION_METHOD, random_state=RANDOM_STATE)
    plt.figure(figsize=(8,6))
    plt.scatter(Z[:,0], Z[:,1], c=labels, s=10)
    plt.title('Customer clusters (2D projection)')
    plt.xlabel('Component 1')
    plt.ylabel('Component 2')
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## Phân tích đặc trưng của từng cụm: Top 10 luật kết hợp
#
# Sau khi phân cụm, ta tính trung bình điểm số (weighted score) của từng luật trong mỗi cụm.
# Luật nào có điểm trung bình cao nhất → đặc trưng nhất cho cụm đó.

# %%
# Đọc kết quả phân cụm đã lưu
cluster_output_path = OUTPUT_CLUSTER_PATH  # đã định nghĩa ở phần parameters
df_clusters = pd.read_csv(cluster_output_path)

print(f"Đã tải {df_clusters.shape[0]} khách hàng với {df_clusters['cluster'].nunique()} cụm")
df_clusters.head()
# Out:
# Đã tải 3921 khách hàng với 4 cụm
#   CustomerID  cluster
# 0     000nan        1
# 1     012346        0
# 2     012747        0
# 3     012748        1
# 4     012749        0

# %%
# Khởi tạo lại clusterer để lấy rules và tên cột đặc trưng
clusterer = RuleBasedCustomerClusterer(df_clean=df_clean)

# Tải lại rules (giống như ở trên)
rules_df = clusterer.load_rules(
    rules_csv_path=RULES_INPUT_PATH,
    top_k=TOP_K_RULES,
    sort_by=SORT_RULES_BY,
)

# Xây dựng lại ma trận đặc trưng X (cùng tham số như lúc clustering)
X, meta = clusterer.build_final_features(
    weighting=WEIGHTING,
    use_rfm=USE_RFM,
    rfm_scale=RFM_SCALE,
    rule_scale=RULE_SCALE,
)

# Danh sách tên cột
feature_columns = []
if USE_RFM:
    feature_columns += ['Recency', 'Frequency', 'Monetary']
feature_columns += rules_df['rule_str'].tolist()  # tên luật dạng "A, B → C"

# DataFrame đặc trưng có index là CustomerID
df_features = pd.DataFrame(X, index=meta['CustomerID'], columns=feature_columns)

# Gắn nhãn cụm vào df_features
df_features = df_features.merge(
    df_clusters[['CustomerID', 'cluster']],
    left_index=True,
    right_on='CustomerID',
    how='left'
)

# Loại bỏ khách hàng không có nhãn cụm (nếu có)
df_features = df_features.dropna(subset=['cluster'])
df_features['cluster'] = df_features['cluster'].astype(int)

print(f"Ma trận đặc trưng cuối cùng: {df_features.shape}")
# Out:
# Ma trận đặc trưng cuối cùng: (3921, 252)

# %%
# Chỉ lấy các cột là luật (loại RFM và Cluster)
rule_columns = [col for col in df_features.columns if col not in ['CustomerID','Recency', 'Frequency', 'Monetary','cluster']]

# Group by cụm và tính trung bình cho từng luật
cluster_rule_means = df_features.groupby('cluster')[rule_columns].mean()

# Hiển thị top 10 luật cho từng cụm
n_top = 5

print(f"\n=== TOP {n_top} LUẬT ĐẶC TRƯNG CHO TỪNG CỤM ===\n")

for cluster in sorted(cluster_rule_means.index):
    top_rules = cluster_rule_means.loc[cluster].sort_values(ascending=False).head(n_top)
    
    print(f"🔸 CỤM {cluster} ({len(df_features[df_features['cluster'] == cluster])} khách hàng)")
    for rule, score in top_rules.items():
        print(f"   → {rule}   (điểm tb: {score:.4f})")
    print()
# Out:
# === TOP 5 LUẬT ĐẶC TRƯNG CHO TỪNG CỤM ===
#
# 🔸 CỤM 0 (3686 khách hàng)
#    → HAND WARMER SCOTTY DOG DESIGN → HAND WARMER RED RETROSPOT   (điểm tb: 0.0751)
#    → WOODEN HEART CHRISTMAS SCANDINAVIAN → WOODEN TREE CHRISTMAS SCANDINAVIAN   (điểm tb: 0.0749)
#    → WOODEN HEART CHRISTMAS SCANDINAVIAN → WOODEN STAR CHRISTMAS SCANDINAVIAN   (điểm tb: 0.0749)
#    → WOODEN STAR CHRISTMAS SCANDINAVIAN → WOODEN HEART CHRISTMAS SCANDINAVIAN   (điểm tb: 0.0727)
#    → WOODEN STAR CHRISTMAS SCANDINAVIAN → WOODEN TREE CHRISTMAS SCANDINAVIAN   (điểm tb: 0.0727)
#
# 🔸 CỤM 1 (8 khách hàng)
#    → HERB MARKER PARSLEY, HERB MARKER ROSEMARY → HERB MARKER THYME   (điểm tb: 1.0000)
#    → HERB MARKER ROSEMARY → HERB MARKER PARSLEY   (điểm tb: 1.0000)
#    → HERB MARKER PARSLEY, HERB MARKER ROSEMARY → HERB MARKER MINT   (điểm tb: 1.0000)
#    → HERB MARKER ROSEMARY → HERB MARKER CHIVES    (điểm tb: 1.0000)
#    → HERB MARKER PARSLEY, HERB MARKER THYME → HERB MARKER MINT   (điểm tb: 1.0000)
#
# 🔸 CỤM 2 (116 khách hàng)
#    → HERB MARKER THYME → HERB MARKER MINT   (điểm tb: 0.9741)
#    → HERB MARKER THYME → HERB MARKER CHIVES    (điểm tb: 0.9741)
#    → HERB MARKER THYME → HERB MARKER PARSLEY   (điểm tb: 0.9741)
#    → HERB MARKER THYME → HERB MARKER BASIL   (điểm tb: 0.9741)
#    → HERB MARKER THYME → HERB MARKER ROSEMARY   (điểm tb: 0.9741)
#
# 🔸 CỤM 3 (111 khách hàng)
#    → CHARLOTTE BAG SUKI DESIGN, RED RETROSPOT CHARLOTTE BAG → STRAWBERRY CHARLOTTE BAG   (điểm tb: 0.9189)
#    → RED RETROSPOT CHARLOTTE BAG, STRAWBERRY CHARLOTTE BAG → CHARLOTTE BAG PINK POLKADOT   (điểm tb: 0.8468)
#    → CHARLOTTE BAG SUKI DESIGN, STRAWBERRY CHARLOTTE BAG → WOODLAND CHARLOTTE BAG   (điểm tb: 0.8198)
#    → RED RETROSPOT CHARLOTTE BAG, WOODLAND CHARLOTTE BAG → CHARLOTTE BAG PINK POLKADOT   (điểm tb: 0.7658)
#    → RED RETROSPOT CHARLOTTE BAG, WOODLAND CHARLOTTE BAG → STRAWBERRY CHARLOTTE BAG   (điểm tb: 0.7658)
